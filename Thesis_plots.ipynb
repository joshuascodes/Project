# %%
# %matplotlib inline
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('C:\\Users\Joshu\OneDrive\Thesis.2020\Final stretch\Data\Correct Data')
print("Current Working Directory " , os.getcwd())
# Out:
# Current Working Directory  C:\Users\Joshu\OneDrive\Thesis.2020\Final stretch\Data\Correct Data

# %%
df=pd.read_excel('wink.xlsx',encoding='utf-8')

# %%
df.index = pd.to_datetime(df['Date'], format = '%Y%m%d')

# %%
df.drop(['Date'], axis = 1)
# Out:
#              Tobinsq  Permits  Starts  Investment
# Date
# 1979-10-01  1.724587    148.0     238         NaN
# 1980-01-01  1.717869    144.5     151         NaN
# 1980-04-01  1.651567    185.4     203         NaN
# 1980-07-01  1.664861    231.8     273         NaN
# 1980-10-01  1.689628    143.1     225         NaN
# ...              ...      ...     ...         ...
# 1999-10-01  2.041897    253.4     301       192.8
# 2000-01-01  2.039949    315.7     278       198.0
# 2000-04-01  2.086706    332.6     357       193.8
# 2000-07-01  2.077695    310.2     320       186.5
# 2000-10-01  2.131156    247.0     275       185.8
#
# [85 rows x 4 columns]

# %%
df.set_index('Date', inplace=True)

# %% [markdown]
# Show all 4 series

# %%
Z = ('-', '-', '-')
sns.set_style()
sns.set_style("whitegrid", custom_style)
sns.set_palette("cubehelix", 1)
plt.xlabel("Year")
fig = sns.lineplot(data = df, style = 'Z', dashes = False)
plt.draw()

# %% [markdown]
# #### Seaborn plot

# %%
os.chdir('C:\\Users\Joshu\OneDrive\Thesis.2020\Final stretch\Data\Correct Data')
print("Current Working Directory " , os.getcwd())
# Out:
# Current Working Directory  C:\Users\Joshu\OneDrive\Thesis.2020\Final stretch\Data\Correct Data

# %%
df2=pd.read_excel('wink.xlsx',encoding='utf-8')

# %%
df2.isna().sum()
df2.dtypes
df2.head()
# Out:
#         Date   Tobinsq  Permits  Starts  Investment
# 0 1979-10-01  1.724587    148.0     238         NaN
# 1 1980-01-01  1.717869    144.5     151         NaN
# 2 1980-04-01  1.651567    185.4     203         NaN
# 3 1980-07-01  1.664861    231.8     273         NaN
# 4 1980-10-01  1.689628    143.1     225         NaN

# %%
sns.relplot(x="Date", y="Investment", hue = "Tobinsq", data=df2, aspect = 2);

# %%
sns.relplot(x="Date", y="Starts", hue = "Tobinsq", data=df2, aspect = 2);

# %%
sns.relplot(x="Date", y="Permits", hue = "Tobinsq", data=df2, aspect = 2);

# %% [markdown]
# The plots for permits and starts in 1985 show there were roughly 300 (measured in thousands) starts and permits, however Tobin's Q is relativly low during this time.
#
# In 2000, roughly the same amount of starts & permits were issued, and the value for Tobins Q is much higher then it was in 1985. This shows that Tobin's Q is not dependent on starts or permits.

# %% [markdown]
# ### Rebase Tobin's Q so that the new home price index and existing home price index use the base year 1975

# %%
os.chdir('C:\\Users\Joshu\OneDrive\Thesis.2020\Final stretch\Data\Tobins_Historical')
print("Current Working Directory " , os.getcwd())
# Out:
# Current Working Directory  C:\Users\Joshu\OneDrive\Thesis.2020\Final stretch\Data\Tobins_Historical

# %%
df3 =pd.read_excel('Tobin3.xlsx',encoding='utf-8', index_col=0, parse_dates=True)
df3 = df3.rename(columns={"jud" : "Q ratio (base years 1980 \& 1996)",  "jud_base75" : "Q ratio (base year 1975)"})

df3.head()
# Out:
#             Q ratio (base years 1980 \& 1996)  Q ratio (base year 1975)
# Year
# 1975-01-01                           1.809589                  1.001001
# 1975-04-01                           1.818204                  1.005766
# 1975-07-01                           1.808176                  1.000219
# 1975-10-01                           1.790942                  0.990686
# 1976-01-01                           1.784650                  0.987206

# %% [markdown]
# #### Set the plot styles

# %%
from datetime import datetime, timedelta
from matplotlib import rcParams
plt.rc('font', family='serif', serif='Times')
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=11)
plt.rc('ytick', labelsize=11)
plt.rc('axes', labelsize=11)


sns.set(rc={'figure.figsize':(7.0, 5)})
custom_style = {'figure.facecolor': 'white',
               'axes.labelcolor': 'black',
               'text.color': 'black',
                'xtick.color': 'black',
                'ytick.color': 'black',
               'axes.edgecolor': '.4'}

# %%
Z = ('-', '-', '-')
sns.set_style()
sns.set_style("whitegrid", custom_style)
sns.set_palette("cubehelix", 1)
plt.xlabel("Year")
plt.ylabel("Q Ratio")

fig = sns.lineplot(data = df3, style = 'Z', dashes = False)
plt.draw()

#plt.savefig('C:\\Users\Joshu\OneDrive\Thesis.2020\Final stretch\images\Q_plotYES.JPEG', dpi=250);
plt.show();

# %% [markdown]
# Show all the series
